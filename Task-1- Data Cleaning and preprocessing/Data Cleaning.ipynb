# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Ghansham Belekar\\OneDrive\\Desktop\\Salesdata.csv")

# %%
display(df)
# Out:
#       country  order_value_EUR       cost         date     category  \
# 0      Sweden         17,524.02   14122.61   2/12/2020        Books
# 1     Finland        116,563.40   92807.78   9/26/2019        Games
# 2    Portugal        296,465.56  257480.34   7/11/2019     Clothing
# 3    Portugal         74,532.02   59752.32    4/2/2020       Beauty
# 4       Spain        178,763.42  146621.76  12/22/2019        Games
# ..        ...               ...        ...         ...          ...
# 995    France         46,296.26   40319.41   5/15/2020        Games
# 996   Belgium        118,061.05  101131.10    7/2/2020   Appliances
# 997   Finland         74,480.56   60023.88    3/6/2020     Clothing
# 998     Spain         87,205.01   69171.01   6/18/2020        Games
# 999  Portugal        107,716.72   86679.64   1/18/2020  Accessories
#
#                   customer_name    sales_manager            sales_rep  \
# 0               Goldner-Dibbert     Maxie Marrow        Madelon Bront
# ...

# %%
df.isnull().sum()
# Out:
# country              0
#  order_value_EUR     0
#  cost                0
# date                 0
# category             0
# customer_name        0
# sales_manager        0
# sales_rep            0
# device_type          0
# order_id             0
# dtype: int64

# %%
df.dtypes
# Out:
# country               object
#  order_value_EUR      object
#  cost                float64
# date                  object
# category              object
# customer_name         object
# sales_manager         object
# sales_rep             object
# device_type           object
# order_id              object
# dtype: object

# %%
columns=["country", "category", "device_type","customer_name", "sales_manager", "sales_rep"]
for column in columns:
    df[column]=df[column].astype('string')

# %%
df.dtypes
# Out:
# country              string[python]
#  order_value_EUR             object
#  cost                       float64
# date                         object
# category             string[python]
# customer_name        string[python]
# sales_manager        string[python]
# sales_rep            string[python]
# device_type          string[python]
# order_id                     object
# dtype: object

# %%
df.columns = [c.strip().lower().replace(' ', '_') for c in df.columns]

# %%
df.dtypes
# Out:
# country            string[python]
# order_value_eur            object
# cost                      float64
# date                       object
# category           string[python]
# customer_name      string[python]
# sales_manager      string[python]
# sales_rep          string[python]
# device_type        string[python]
# order_id                   object
# dtype: object

# %%
df['order_value_eur']=df['order_value_eur'].astype('string').str.replace(',','',regex=False).astype(float)

# %%
display(df)
# Out:
#       country  order_value_eur       cost        date     category  \
# 0      Sweden         17524.02   14122.61   2/12/2020        Books
# 1     Finland        116563.40   92807.78   9/26/2019        Games
# 2    Portugal        296465.56  257480.34   7/11/2019     Clothing
# 3    Portugal         74532.02   59752.32    4/2/2020       Beauty
# 4       Spain        178763.42  146621.76  12/22/2019        Games
# ..        ...              ...        ...         ...          ...
# 995    France         46296.26   40319.41   5/15/2020        Games
# 996   Belgium        118061.05  101131.10    7/2/2020   Appliances
# 997   Finland         74480.56   60023.88    3/6/2020     Clothing
# 998     Spain         87205.01   69171.01   6/18/2020        Games
# 999  Portugal        107716.72   86679.64   1/18/2020  Accessories
#
#                   customer_name    sales_manager            sales_rep  \
# 0               Goldner-Dibbert     Maxie Marrow        Madelon Bront
# ...
